 'X', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['D', 'S', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'R', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['E', 'K', 'C', '2', '2', '2', '2', '2', '2', '1', '0'],
           ['F', 'S', 'I', '2', '2', '1', '2', '2', '1', '1', '2'],
           ['H', 'S', 'X', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['D', 'S', 'O', '1', '3', '1', '2', '2', '1', '1', '0'],
           ['D', 'A', 'I', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['H', 'A', 'X', '1', '3', '1', '1', '1', '1', '1', '0'],
           ['D', 'S', 'O', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['C', 'S', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '2', '1', '1', '1', '0'],
           ['E', 'K', 'C', '2', '3', '1', '2', '2', '2', '1', '2'],
           ['F', 'A', 'I', '2', '2', '1', '2', '2', '1', '1', '0'],
           ['C', 'S', 'O', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['D', 'A', 'I', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['H', 'A', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['B', 'X', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '3', '1', '1', '1', '1', '1', '0'],
           ['D', 'A', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['D', 'H', 'O', '1', '3', '1', '2', '2', '1', '1', '0'],
           ['E', 'K', 'C', '2', '2', '1', '2', '2', '1', '1', '0'],
           ['F', 'A', 'I', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['C', 'S', 'O', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['D', 'A', 'I', '1', '1', '1', '2', '2', '1', '1', '1'],
           ['H', 'A', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['D', 'A', 'O', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['D', 'H', 'O', '1', '3', '1', '2', '2', '1', '1', '0'],
           ['D', 'S', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '1', '1', '2', '2', '1', '1', '0'],
           ['F', 'S', 'I', '1', '3', '1', '2', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '3', '1', '1', '1', '1', '1', '0'],
           ['B', 'X', 'I', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['D', 'H', 'O', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['D', 'R', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['D', 'A', 'I', '2', '3', '2', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['C', 'R', 'O', '1', '3', '1', '1', '2', '1', '1', '1'],
           ['C', 'R', 'O', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['D', 'H', 'O', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['C', 'S', 'O', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['E', 'A', 'I', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '1', '1', '1', '1'],
           ['C', 'S', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['D', 'S', 'O', '1', '3', '1', '2', '2', '1', '1', '0'],
           ['B', 'X', 'O', '1', '1', '1', '1', '2', '1', '1', '0'],
           ['E', 'A', 'O', '1', '2', '1', '2', '2', '1', '1', '4'],
           ['H', 'S', 'X', '1', '3', '1', '1', '1', '1', '1', '1'],
           ['H', 'S', 'X', '1', '3', '1', '1', '1', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '2', '1', '1', '1'],
           ['D', 'H', 'O', '1', '3', '1', '2', '2', '1', '1', '0'],
           ['E', 'A', 'I', '2', '2', '1', '2', '2', '1', '1', '0'],
           ['D', 'S', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '1', '1', '1', '1', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '2', '1', '1', '1'],
           ['D', 'S', 'O', '1', '2', '1', '2', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '2', '2', '2', '1', '1', '0'],
           ['H', 'S', 'X', '2', '2', '1', '1', '2', '1', '1', '0'],
           ['D', 'R', 'O', '1', '3', '1', '1', '2', '1', '1', '0'],
           ['H', 'S', 'X', '1', '2', '1', '1', '1', '1', '1', '0'],
           ['H', 'S', 'X', '2', '2', '1', '1', '2', '1', '1', '0'],
           ['C', 'S', 'O', '1', '2', '1', '2', '2', '1', '1', '0']]

# %%
# Get % from user 
X = input()

# Get criterion from user 
criterion = input()

# Encoder
encoder = OrdinalEncoder()
encoder.fit([dataset[j][:-1] for j in range(0, len(dataset))])

# Split dataset: train_csv 
train_csv = dataset[:int((1-float(X)/100)*len(dataset))]
test_csv = dataset[int((1-float(X)/100)*len(dataset)):]

#2. Load X from train, encode
X = [train_csv[j][:-1] for j in range(0, len(train_csv))]
X = encoder.transform(X)

#3. Load y from train
y = [train_csv[j][-1] for j in range(0, len(train_csv))]

#4. classifier, .ft(X,y)
classifier = DecisionTreeClassifier(criterion=criterion, random_state=0)
classifier.fit(X, y)

#5. Load X from test, encode
X_test = [test_csv[j][:-1] for j in range(0, len(test_csv))]
X_test = encoder.transform(X_test)

#6. Load y from test
y_test = [test_csv[j][-1] for j in range(0, len(test_csv))]

#7. y_pred
y_pred = [classifier.predict([x])[0] for x in X_test]

#8. accuracy_score
print(f'Accuracy: {accuracy_score(y_pred, y_test, normalize=True)}')

# Depth
print(f'Depth: {classifier.get_depth()}')

# Number of leaves
print(f'Number of leaves: {classifier.get_n_leaves()}')

# Load features_importance
feature_importance = list(classifier.feature_importances_)

# Most important feature 
print('Most important feature: ', feature_importance.index(max(feature_importance)))
print('Least important feature: ', feature_importance.index(min(feature_importance)))
# Out:
# 50
# entropy
# Accuracy: 0.7916063675832128
# Depth: 14
# Number of leaves: 165
# Most important feature:  0
# Least important feature:  7
